# %% [markdown]
# # Limpieza de bienes raíces
#
# Este es un conjunto de datos (dataset) reales que fue descargado usando técnicas de web scraping. La data contiene registros de **Fotocasa**, el cual es uno de los sitios más populares de bienes raíces en España. Por favor no hagas esto (web scraping) a no ser que sea para propósitos académicos.
#
# El dataset fue descargado hace algunos años por Henry Navarro y en ningún caso se obtuvo beneficio económico de ello.
#
# Contiene miles de datos de casas reales publicadas en la web www.fotocasa.com. Tu objetivo es extraer tanta información como sea posible con el conocimiento que tienes hasta ahora de ciencia de datos, por ejemplo ¿cuál es la casa más cara en todo el dataset?
#
# Empecemos precisamente con esa pregunta... ¡Buena suerte!

# %% [markdown]
# #### Ejercicio 00. Lee el dataset assets/real_estate.csv e intenta visualizar la tabla (★☆☆)

# %%
import pandas as pd

# Este archivo CSV contiene puntos y comas en lugar de comas como separadores
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### Ejercicio 01. ¿Cuál es la casa más cara en todo el dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle del Prado, Nº20 es la más cara y su precio es de 5000000 USD`

# %%
# Imprimir los nombres de las columnas
print(ds.columns.tolist())

# Encontrar la fila con el precio máximo
casa_mas_cara = ds.loc[ds['price'].idxmax()]

# Obtener la dirección y el precio de la casa más cara
direccion_casa_cara = casa_mas_cara['address']
precio_casa_cara = casa_mas_cara['price']

# Imprimir la dirección y el precio de la casa más cara
print(f"La casa con dirección en {direccion_casa_cara} es la más cara y su precio es de {precio_casa_cara} USD")
# Out:
# ['Unnamed: 0', 'id_realEstates', 'isNew', 'realEstate_name', 'phone_realEstate', 'url_inmueble', 'rooms', 'bathrooms', 'surface', 'price', 'date', 'description', 'address', 'country', 'level1', 'level2', 'level3', 'level4', 'level5', 'level6', 'level7', 'level8', 'upperLevel', 'countryId', 'level1Id', 'level2Id', 'level3Id', 'level4Id', 'level5Id', 'level6Id', 'level7Id', 'level8Id', 'accuracy', 'latitude', 'longitude', 'zipCode', 'customZone']
# La casa con dirección en El Escorial es la más cara y su precio es de 8500000 USD

# %% [markdown]
# #### Ejercicio 02. ¿Cuál es la casa más barata del dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle Alcalá, Nº58 es la más barata y su precio es de 12000 USD`

# %%
# Filtrar el dataset para excluir precios cero
ds_filtrado = ds[ds['price'] > 0]

# Encontrar la fila con el precio mínimo en el dataset filtrado
casa_mas_barata = ds_filtrado.loc[ds_filtrado['price'].idxmin()]

# Obtener la dirección y el precio de la casa más barata
direccion_casa_barata = casa_mas_barata['address']
precio_casa_barata = casa_mas_barata['price']

# Imprimir la dirección y el precio de la casa más barata
print(f"La casa con dirección en {direccion_casa_barata} es la más barata y su precio es de {precio_casa_barata} USD")
# Out:
# La casa con dirección en Berlin, Coslada es la más barata y su precio es de 600 USD

# %% [markdown]
# #### Ejercicio 03. ¿Cuál es la casa más grande y la más pequeña del dataset? (★☆☆)
#
# Imprime la dirección y el área de las casas seleccionadas. Por ejemplo:
#
# `La casa más grande está ubicada en Calle Gran Vía, Nº38 y su superficie es de 5000 metros`
#
# `La casa más pequeña está ubicada en Calle Mayor, Nº12 y su superficie es de 200 metros`

# %%
# Encontrar la fila con la superficie máxima
casa_mas_grande = ds.loc[ds['surface'].idxmax()]
direccion_mas_grande = casa_mas_grande['address']
superficie_mas_grande = casa_mas_grande['surface']

# Encontrar la fila con la superficie mínima
casa_mas_pequena = ds.loc[ds['surface'].idxmin()]
direccion_mas_pequena = casa_mas_pequena['address']
superficie_mas_pequena = casa_mas_pequena['surface']

# Imprimir los resultados
print(f"La casa más grande está ubicada en {direccion_mas_grande} y su superficie es de {superficie_mas_grande} metros")
print(f"La casa más pequeña está ubicada en {direccion_mas_pequena} y su superficie es de {superficie_mas_pequena} metros")
# Out:
# La casa más grande está ubicada en Sevilla la Nueva y su superficie es de 249000.0 metros
# La casa más pequeña está ubicada en Calle Amparo,  Madrid Capital y su superficie es de 15.0 metros

# %% [markdown]
# #### Ejercicio 04. ¿Cuantas poblaciones (columna level5) contiene el dataset? (★☆☆)
#
# Imprime el nombre de las poblaciones separadas por coma. Por ejemplo:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
# Obtener las poblaciones únicas (excluyendo NaN) y contar con nunique()
poblaciones_unicas = ds['level5'].dropna().unique()  # Excluye NaN antes de obtener únicos
num_poblaciones = ds['level5'].nunique()  # nunique() ya excluye NaN por defecto

# Convertir a lista y unir los nombres
lista_poblaciones = poblaciones_unicas.tolist()
nombres_poblaciones = ', '.join(lista_poblaciones)

# Imprimir resultados
print("Poblaciones en el dataset:")
print(nombres_poblaciones)
print(f"\nNúmero total de poblaciones únicas: {num_poblaciones}")
# Out:
# Poblaciones en el dataset:
# ...

# %% [markdown]
# #### Ejercicio 05. ¿El dataset contiene valores no admitidos (NAs)? (★☆☆)
#
# Imprima un booleano (`True` o `False`) seguido de la fila/columna que contiene el NAs.

# %%
# Verificar si hay algún valor nulo en todo el DataFrame
tiene_nulos = ds.isnull().any().any()

# Obtener las columnas que contienen al menos un valor nulo
columnas_con_nulos = ds.columns[ds.isnull().any()].tolist()

# Imprimir el resultado booleano
print(tiene_nulos)

# Imprimir las columnas con valores nulos
print(columnas_con_nulos)
# Out:
# True
# ['realEstate_name', 'phone_realEstate', 'rooms', 'bathrooms', 'surface', 'description', 'level4', 'level6', 'level7', 'level8', 'zipCode', 'customZone']

# %% [markdown]
# #### Ejercicio 06. Elimina los NAs del dataset, si aplica (★★☆)
#
# Imprima una comparación entre las dimensiones del DataFrame original versus el DataFrame después de las eliminaciones.

# %%
# Obtener el tamaño del DataFrame antes de eliminar los NAs
tamaño_antes = ds.shape

# Eliminar las filas que contienen al menos un valor nulo
ds_sin_nulos = ds.dropna()

# Obtener el tamaño del DataFrame después de eliminar los NAs
tamaño_despues = ds_sin_nulos.shape

# Imprimir los tamaños antes y después
print(f"Tamaño del DataFrame antes de eliminar NAs: {tamaño_antes}")
print(f"Tamaño del DataFrame después de eliminar NAs: {tamaño_despues}")

# Calcular la diferencia en el número de filas
diferencia_filas = tamaño_antes[0] - tamaño_despues[0]
print(f"Número de filas eliminadas: {diferencia_filas}")
# Out:
# Tamaño del DataFrame antes de eliminar NAs: (15335, 37)
# Tamaño del DataFrame después de eliminar NAs: (0, 37)
# Número de filas eliminadas: 15335

# %% [markdown]
# #### Ejercicio 07. ¿Cuál la media de precios en la población (columna level5) de "Arroyomolinos (Madrid)"? (★★☆)
#
# Imprima el valor obtenido.

# %%
# Filtrar el DataFrame para la población de "Arroyomolinos (Madrid)"
arroyomolinos_data = ds[ds['level5'] == 'Arroyomolinos (Madrid)']

# Calcular la media de los precios en esa población
media_precios_arroyomolinos = arroyomolinos_data['price'].mean()

# Imprimir la media de precios
print(f"La media de precios en Arroyomolinos (Madrid) es: {media_precios_arroyomolinos} EUR")
# Out:
# La media de precios en Arroyomolinos (Madrid) es: 294541.59854014596 EUR

# %% [markdown]
# #### Ejercicio 08. Trazar el histograma de los precios para la población (level5 column) de "Arroyomolinos (Madrid)" y explica qué observas (★★☆)
#
# Imprime el histograma de los precios y escribe en la celda del Markdown un breve análisis del trazado.

# %%
import matplotlib.pyplot as plt
# Trazar el histograma de los precios
plt.figure(figsize=(10, 6))
plt.hist(arroyomolinos_data['price'], bins=10, edgecolor='black')
plt.title('Histograma de Precios en Arroyomolinos (Madrid)')
plt.xlabel('Precio (EUR)')
plt.ylabel('Frecuencia')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %% [markdown]
# la mayoria de los precios esta centrada en este medio y no hay mucho rango de distribuicion de los precios. Muy pocos son muy caros y fuera de este medio, y unos pocos tambien estan por abajo de este cuadro medio.

# %% [markdown]
# #### Ejercicio 09. ¿Son los precios promedios de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios y escribe una conclusión sobre ellos.

# %%
# Calcular el precio promedio para Valdemorillo
valdemorillo_data = ds[ds['level5'] == 'Valdemorillo']
precio_promedio_valdemorillo = valdemorillo_data['price'].mean()

# Calcular el precio promedio para Galapagar
galapagar_data = ds[ds['level5'] == 'Galapagar']
precio_promedio_galapagar = galapagar_data['price'].mean()

# Imprimir los precios promedios
print(f"Precio promedio en Valdemorillo: {precio_promedio_valdemorillo:.2f} EUR")
print(f"Precio promedio en Galapagar: {precio_promedio_galapagar:.2f} EUR")

# Conclusión
if abs(precio_promedio_valdemorillo - precio_promedio_galapagar) < 10000:
    print("\nConclusión: Los precios promedios en Valdemorillo y Galapagar son similares.")
else:
    print("\nConclusión: Los precios promedios en Valdemorillo y Galapagar son significativamente diferentes.")
# Out:
# Precio promedio en Valdemorillo: 363860.29 EUR
# Precio promedio en Galapagar: 360063.20 EUR
#
# Conclusión: Los precios promedios en Valdemorillo y Galapagar son similares.

# %% [markdown]
# #### Ejercicio 10. ¿Son los promedios de precio por metro cuadrado (precio/m2) de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios de precio por metro cuadrado y escribe una conclusión sobre ellos.
#
# Pista: Crea una nueva columna llamada `pps` (*price per square* o precio por metro cuadrado) y luego analiza los valores.

# %%
# Calcular el precio por metro cuadrado (pps)
ds['pps'] = ds['price'] / ds['surface']

# Calcular el precio promedio por metro cuadrado para Valdemorillo
valdemorillo_data = ds[ds['level5'] == 'Valdemorillo']
precio_pps_valdemorillo = valdemorillo_data['pps'].mean()

# Calcular el precio promedio por metro cuadrado para Galapagar
galapagar_data = ds[ds['level5'] == 'Galapagar']
precio_pps_galapagar = galapagar_data['pps'].mean()

# Imprimir los precios promedio por metro cuadrado
print(f"Precio promedio por metro cuadrado en Valdemorillo: {precio_pps_valdemorillo:.2f} EUR/m2")
print(f"Precio promedio por metro cuadrado en Galapagar: {precio_pps_galapagar:.2f} EUR/m2")

# Conclusión sobre los precios promedio por metro cuadrado
if abs(precio_pps_valdemorillo - precio_pps_galapagar) < 100:  # Se usa un umbral de 100 EUR/m2 para considerar "similares"
    print("\nConclusión: Los precios promedio por metro cuadrado en Valdemorillo y Galapagar son similares.")
else:
    print("\nConclusión: Los precios promedio por metro cuadrado en Valdemorillo y Galapagar son significativamente diferentes.")
# Out:
# Precio promedio por metro cuadrado en Valdemorillo: 1317.95 EUR/m2
# Precio promedio por metro cuadrado en Galapagar: 1606.32 EUR/m2
#
# Conclusión: Los precios promedio por metro cuadrado en Valdemorillo y Galapagar son significativamente diferentes.

# %% [markdown]
# #### Ejercicio 11. Analiza la relación entre la superficie y el precio de las casas. (★★☆)
#
# Pista: Puedes hacer un `scatter plot` y luego escribir una conclusión al respecto.

# %%
# Crear el scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(ds['surface'], ds['price'], alpha=0.5)  # alpha para transparencia
plt.title('Relación entre Superficie y Precio de las Casas')
plt.xlabel('Superficie (metros cuadrados)')
plt.ylabel('Precio (EUR)')
plt.grid(True)
plt.show()

# %% [markdown]
# Superficie en metros cuadrados (desde 0 hasta ~250,000 m², aunque esto parece inusual para viviendas). Rango de Precios en EUR (desde 0 hasta 250,000 EUR).
# Relación positiva esperada: Normalmente, a mayor superficie, mayor precio. Si los puntos siguen una tendencia ascendente, esto confirmaría esa correlación.
# Enseguida vamos a filtrar datos incorrectos: Eliminar filas con precio = 0 o superficie > 10,000 m²

# %%
# Filtrar datos incorrectos:
# - Eliminar precios = 0 (posibles errores o anuncios sin precio)
# - Eliminar superficies > 10,000 m² (demasiado grandes para viviendas normales)
# - Eliminar posibles valores negativos (por si existen)
ds_filtrado = ds[(ds['price'] > 0) & 
                (ds['surface'] > 0) & 
                (ds['surface'] < 10000)]

# Crear el scatter plot con datos filtrados
plt.figure(figsize=(10, 6))
plt.scatter(ds_filtrado['surface'], ds_filtrado['price'], 
            alpha=0.5,
            color='blue',
            edgecolor='w')  # Puntos semitransparentes con borde blanco

# Añadir título y etiquetas
plt.title('Relación entre Superficie y Precio de las Casas (Datos Filtrados)')
plt.xlabel('Superficie (metros cuadrados)')
plt.ylabel('Precio (EUR)')

# Añadir grid y ajustar límites de ejes
plt.grid(True, linestyle='--', alpha=0.7)

# Opcional: Añadir línea de regresión para ver tendencia
import numpy as np
from scipy import stats

# Calcular regresión lineal
slope, intercept, r_value, p_value, std_err = stats.linregress(ds_filtrado['surface'], ds_filtrado['price'])
x = np.linspace(ds_filtrado['surface'].min(), ds_filtrado['surface'].max(), 100)
y = slope * x + intercept

plt.plot(x, y, color='red', label=f'Tendencia (R² = {r_value**2:.2f})')
plt.legend()

plt.show()

# Mostrar estadísticas de los datos filtrados
print(f"Datos originales: {len(ds)} registros")
print(f"Datos filtrados: {len(ds_filtrado)} registros")
print(f"Se eliminaron {len(ds) - len(ds_filtrado)} registros con valores atípicos")
# Out:
# Datos originales: 15335 registros
# Datos filtrados: 14027 registros
# Se eliminaron 1308 registros con valores atípicos

# %% [markdown]
# #### Ejercicio 12. ¿Cuántas agencia de bienes raíces contiene el dataset? (★★☆)
#
# Imprime el valor obtenido.

# %%
# Contar el número de agencias de bienes raíces únicas
num_agencias = ds['realEstate_name'].nunique()

# Imprimir el resultado
print(f"\nEl dataset contiene {num_agencias} agencias de bienes raíces únicas.")
# Out:
# El dataset contiene 1821 agencias de bienes raíces únicas.

# %% [markdown]
# #### Ejercicio 13. ¿Cuál es la población (columna level5) que contiene la mayor cantidad de casas?(★★☆)
#
# Imprima la población y el número de casas.

# %%
# Contar el número de apariciones de cada población en la columna 'level5'
poblacion_counts = ds['level5'].value_counts()

# Encontrar la población con el mayor número de casas
poblacion_max_casas = poblacion_counts.idxmax()
num_casas_max_poblacion = poblacion_counts.max()

# Imprimir la población y el número de casas
print(f"\nLa población con la mayor cantidad de casas es {poblacion_max_casas} con {num_casas_max_poblacion} casas.")
# Out:
# La población con la mayor cantidad de casas es  Madrid Capital con 6643 casas.

# %% [markdown]
# #### Ejercicio 14. Ahora vamos a trabajar con el "cinturón sur" de Madrid. Haz un subconjunto del DataFrame original que contenga las siguientes poblaciones (columna level5): "Fuenlabrada", "Leganés", "Getafe", "Alcorcón" (★★☆)
#
# Pista: Filtra el DataFrame original usando la columna `level5` y la función `isin`.

# %%
# Crear un subconjunto del DataFrame para el "cinturón sur" de Madrid
cinturon_sur_poblaciones = ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]
ds_cinturon_sur = ds[ds['level5'].isin(cinturon_sur_poblaciones)]

# Imprimir el subconjunto del DataFrame
print("\nSubconjunto del DataFrame para el cinturón sur de Madrid:")
print(ds_cinturon_sur)
# Out:
# Subconjunto del DataFrame para el cinturón sur de Madrid:
#        Unnamed: 0  id_realEstates  isNew  \
# 1               2       153867863  False
# 3               4       152776331  False
# 85             86       153152077  False
# 94             95       153995577  False
# 109           110       153586414  False
# ...           ...             ...    ...
# 15275       15276       153903887  False
# 15291       15292       151697757  False
# 15305       15306       153902389  False
# 15322       15323       153871864  False
# 15325       15326       153901467  False
#
#                                  realEstate_name  phone_realEstate  \
# 1              tecnocasa fuenlabrada ferrocarril       916358736.0
# 3              tecnocasa fuenlabrada ferrocarril       916358736.0
# 85                       sinergical inmobiliaria               NaN
# 94                               viviendas365com       911226014.0
# 109              area uno asesores inmobiliarios       912664081.0
# ...

# %% [markdown]
# #### Ejercicio 15. Traza un gráfico de barras de la mediana de los precios y explica lo que observas (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprima un gráfico de barras de la mediana de precios y escriba en la celda Markdown un breve análisis sobre el gráfico.

# %%
# Calcular la mediana de los precios por población
mediana_precios_por_poblacion = ds_cinturon_sur.groupby('level5')['price'].median()

# Crear un gráfico de barras de la mediana de los precios
plt.figure(figsize=(10, 6))
mediana_precios_por_poblacion.sort_values().plot(kind='barh', color='skyblue', edgecolor='black') #ordenar de menor a mayor
plt.title('Mediana de Precios de Viviendas en el Cinturón Sur de Madrid')
plt.xlabel('Mediana del Precio (EUR)')
plt.ylabel('Población')
plt.grid(axis='x', alpha=0.75)
plt.show()

# %% [markdown]
# El gráfico de barras muestra la mediana de los precios de las viviendas en las poblaciones del cinturón sur de Madrid: Alcorcón, Fuenlabrada, Getafe y Leganés.
#
# Conclusión:
# Existe una variación en los precios medios de la vivienda entre las diferentes poblaciones del cinturón sur de Madrid.
# Fuenlabrada se posiciona como la opción más económica, seguido de Leganes. Alcorcón y Getafe comparten un rango de precios más elevado.
# Este análisis puede ser útil para compradores o inversores que buscan propiedades en esta zona, ya que les permite identificar las áreas que se ajustan mejor a su presupuesto.

# %% [markdown]
# #### Ejercicio 16. Calcula la media y la varianza de muestra para las siguientes variables: precio, habitaciones, superficie y baños (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprime ambos valores por cada variable.

# %%
# Calcular la media y la varianza para las variables especificadas
variables_a_analizar = ['price', 'rooms', 'surface', 'bathrooms']
for variable in variables_a_analizar:
    media_variable = ds_cinturon_sur[variable].mean()
    varianza_variable = ds_cinturon_sur[variable].var()
    print(f"\nEstadísticas para {variable}:")
    print(f"  Media: {media_variable:.2f}")
    print(f"  Varianza de muestra: {varianza_variable:.2f}")
# Out:
# Estadísticas para price:
#   Media: 223094.48
#   Varianza de muestra: 14921367508.05
#
# Estadísticas para rooms:
#   Media: 3.02
#   Varianza de muestra: 0.72
#
# Estadísticas para surface:
#   Media: 111.75
#   Varianza de muestra: 4263.05
#
# Estadísticas para bathrooms:
#   Media: 1.63
#   Varianza de muestra: 0.57

# %% [markdown]
# #### Ejercicio 17. ¿Cuál es la casa más cara de cada población? Debes usar el subset obtenido en la pregunta 14 (★★☆)
#
# Imprime tanto la dirección como el precio de la casa seleccionada de cada población. Puedes imprimir un DataFrame o una sola línea para cada población.

# %%
# Encontrar la casa más cara en cada población del cinturón sur
casas_mas_caras = ds_cinturon_sur.groupby('level5').apply(lambda x: x.nlargest(1, 'price'))

# Imprimir la dirección y el precio de la casa más cara de cada población
print("\nLa casa más cara en cada población del cinturón sur:")
for poblacion in cinturon_sur_poblaciones:
    direccion = casas_mas_caras.loc[poblacion, 'address'].values[0]
    precio = casas_mas_caras.loc[poblacion, 'price'].values[0]
    print(f"{poblacion}: Dirección: {direccion}, Precio: {precio} EUR")
# Out:
# La casa más cara en cada población del cinturón sur:
# Fuenlabrada: Dirección: Calle de Paulo Freire, 5, Fuenlabrada, Precio: 490000 EUR
# Leganés: Dirección: Avenida Reina Sofía, Leganés, Precio: 650000 EUR
# Getafe: Dirección: Getafe, Precio: 1050000 EUR
# Alcorcón: Dirección: Alcorcón, Precio: 950000 EUR
# /tmp/ipykernel_570/427176989.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   casas_mas_caras = ds_cinturon_sur.groupby('level5').apply(lambda x: x.nlargest(1, 'price'))

# %% [markdown]
# #### Ejercicio 18. Normaliza la variable de precios para cada población y traza los 4 histogramas en el mismo gráfico (debes usar el subconjunto obtenido en la pregunta 14) (★★★)
#
# Para el método de normalización, puedes usar el que consideres adecuado, no hay una única respuesta correcta para esta pregunta. Imprime el gráfico y escribe en la celda de Markdown un breve análisis sobre el gráfico.
#
# Pista: Puedes ayudarte revisando la demostración multihist de Matplotlib.

# %%
# Normalizar los precios por población usando z-score y trazar histogramas
plt.figure(figsize=(12, 8))
for i, poblacion in enumerate(cinturon_sur_poblaciones):
    precios_poblacion = ds_cinturon_sur.loc[ds_cinturon_sur['level5'] == poblacion, 'price']
    precios_normalizados = (precios_poblacion - precios_poblacion.mean()) / precios_poblacion.std() # Normalización Z-Score
    plt.subplot(2, 2, i + 1) # Crear subplot para cada población
    plt.hist(precios_normalizados, bins=10, alpha=0.7, edgecolor='black')
    plt.title(f'Histograma de Precios Normalizados - {poblacion}')
    plt.xlabel('Precio Normalizado')
    plt.ylabel('Frecuencia')
    plt.grid(True)
plt.tight_layout() 
plt.show()

# %% [markdown]
# Forma de la distribución: Después de la normalización, los histogramas permiten comparar la forma de la distribución de precios entre las poblaciones, independientemente de las diferencias en la escala de precios original. Se puede observar si la distribución es simétrica, asimétrica, o si presenta múltiples picos.
# Dispersión: La dispersión de los datos normalizados es comparable entre las poblaciones, ya que la desviación estándar es 1 en todos los casos. Esto facilita la comparación de la variabilidad relativa de los precios.
# Valores atípicos: La normalización ayuda a identificar valores atípicos relativos dentro de cada población. Los valores que se alejan significativamente de 0 en el eje x son aquellos que se desvían mucho del precio medio de su respectiva población.
# Comparación de poblaciones: Aunque los precios originales tenían escalas diferentes, la normalización permite observar si, en términos relativos, hay diferencias en la concentración de precios entre las poblaciones. Por ejemplo, se puede identificar si los precios en una población tienden a agruparse más cerca de la media que en otra.
#
# Conclusión:
# La normalización de los precios revela que, si bien las poblaciones pueden tener rangos de precios absolutos diferentes,
# la distribución relativa de los precios dentro de cada población comparte ciertas características.
# Esto facilita la comparación de la forma de la distribución y la identificación de valores atípicos relativos.

# %% [markdown]
# #### Ejercicio 19. ¿Qué puedes decir sobre el precio por metro cuadrado (precio/m2) entre los municipios de 'Getafe' y 'Alcorcón'? Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
#
# Pista: Crea una nueva columna llamada `pps` (price per square en inglés) y luego analiza los valores

# %%
# Calcular el precio por metro cuadrado (pps) para el subconjunto del cinturón sur
ds_cinturon_sur.loc[:, 'pps'] = ds_cinturon_sur['price'] / ds_cinturon_sur['surface'] # Usa .loc para evitar la advertencia

# Calcular el precio promedio por metro cuadrado para Getafe
getafe_data = ds_cinturon_sur[ds_cinturon_sur['level5'] == 'Getafe']
precio_pps_getafe = getafe_data['pps'].mean()

# Calcular el precio promedio por metro cuadrado para Alcorcón
alcorcon_data = ds_cinturon_sur[ds_cinturon_sur['level5'] == 'Alcorcón']
precio_pps_alcorcon = alcorcon_data['pps'].mean()

# Imprimir los precios promedio por metro cuadrado
print(f"Precio promedio por metro cuadrado en Getafe: {precio_pps_getafe:.2f} EUR/m2")
print(f"Precio promedio por metro cuadrado en Alcorcón: {precio_pps_alcorcon:.2f} EUR/m2")

# Conclusión sobre los precios promedio por metro cuadrado en Getafe y Alcorcón
if abs(precio_pps_getafe - precio_pps_alcorcon) < 100:  # Umbral de 100 EUR/m2
    print("\nConclusión: Los precios promedio por metro cuadrado en Getafe y Alcorcón son similares.")
else:
    print("\nConclusión: Los precios promedio por metro cuadrado en Getafe y Alcorcón son significativamente diferentes.")
# Out:
# Precio promedio por metro cuadrado en Getafe: 2066.31 EUR/m2
# Precio promedio por metro cuadrado en Alcorcón: 2239.30 EUR/m2
#
# Conclusión: Los precios promedio por metro cuadrado en Getafe y Alcorcón son significativamente diferentes.

# %% [markdown]
# #### Ejercicio 20. Realiza el mismo gráfico para 4 poblaciones diferentes (columna level5) y colócalos en el mismo gráfico. Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
# Pista: Haz un diagrama de dispersión de cada población usando subgráficos (subplots).

# %%
# Crear un diagrama de dispersión para 4 poblaciones diferentes en subgráficos
plt.figure(figsize=(12, 10))  # Ajustar el tamaño de la figura para que quepan los subgráficos

for i, poblacion in enumerate(cinturon_sur_poblaciones):
    poblacion_data = ds_cinturon_sur[ds_cinturon_sur['level5'] == poblacion]
    plt.subplot(2, 2, i + 1)  # Crear subgráficos en una cuadrícula de 2x2
    plt.scatter(poblacion_data['surface'], poblacion_data['price'], alpha=0.7)
    plt.title(f'Superficie vs. Precio en {poblacion}')
    plt.xlabel('Superficie (m2)')
    plt.ylabel('Precio (EUR)')
    plt.grid(True)

plt.tight_layout() 
plt.show()

# %% [markdown]
# #### Ejercicio 21. Realiza un trazado de las coordenadas (columnas latitud y longitud) del cinturón sur de Madrid por color de cada población (debes usar el subconjunto obtenido del Ejercicio 14) (★★★★)
#
# Ejecuta la siguiente celda y luego comienza a codear en la siguiente. Debes implementar un código simple que transforme las columnas de coordenadas en un diccionario de Python (agrega más información si es necesario) y agrégala al mapa.

# %%
from ipyleaflet import Map, basemaps

# Mapa centrado en Madrid
map = Map(center = (40.35, -3.8), zoom = 11.5, min_zoom = 1, max_zoom = 20, 
    basemap=basemaps.OpenStreetMap.Mapnik)
map
# Out:
# Map(center=[40.35, -3.8], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_ou…

# %%
from ipyleaflet import Map, basemaps, CircleMarker, LayerGroup
import pandas as pd
from ipywidgets import HTML
from IPython.display import display

# 1. Load and prepare data
ds = pd.read_csv('assets/real_estate.csv', sep=';')
cinturon_sur_poblaciones = ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]
ds_cinturon_sur = ds[ds['level5'].isin(cinturon_sur_poblaciones)].copy()

# 2. Convert and clean coordinates
def clean_coord(coord):
    try:
        if isinstance(coord, str):
            return float(coord.replace(',', '.'))
        return float(coord)
    except (ValueError, TypeError):
        return None

ds_cinturon_sur['latitude'] = ds_cinturon_sur['latitude'].apply(clean_coord)
ds_cinturon_sur['longitude'] = ds_cinturon_sur['longitude'].apply(clean_coord)
ds_cinturon_sur = ds_cinturon_sur.dropna(subset=['latitude', 'longitude'])

# 3. Create map with proper initialization
map_madrid = Map(
    center=(40.30, -3.70),
    zoom=12,
    basemap=basemaps.CartoDB.Positron,
    scroll_wheel_zoom=True
)

# 4. Color palette with high visibility
color_palette = {
    'Fuenlabrada': '#FF0000',
    'Leganés': '#0000FF',
    'Getafe': '#00AA00',
    'Alcorcón': '#AA00AA'
}

# 5. Create LayerGroups for each population
layer_groups = {}
for poblacion in cinturon_sur_poblaciones:
    layer_groups[poblacion] = LayerGroup(layers=[], name=poblacion)
    map_madrid.add_layer(layer_groups[poblacion])

# 6. Add markers with verification
if not ds_cinturon_sur.empty:
    for poblacion in cinturon_sur_poblaciones:
        poblacion_data = ds_cinturon_sur[ds_cinturon_sur['level5'] == poblacion]
        
        if poblacion_data.empty:
            print(f"No data found for {poblacion}")
            continue
            
        for _, row in poblacion_data.iterrows():
            try:
                marker = CircleMarker(
                    location=(row['latitude'], row['longitude']),
                    radius=6,
                    color=color_palette[poblacion],
                    fill_color=color_palette[poblacion],
                    fill_opacity=0.8,
                    weight=1,
                    title=f"{poblacion}"
                )
                layer_groups[poblacion].add_layer(marker) # Use add_layer method
            except Exception as e:
                print(f"Error creating marker for {poblacion}: {str(e)}")
                print(f"Coordinates: {row['latitude']}, {row['longitude']}")

    # 7. Add enhanced legend
    legend_html = HTML('''
    <div style="
        position: fixed;
        bottom: 20px;
        right: 20px;
        z-index: 1000;
        background: white;
        padding: 10px;
        border: 2px solid black;
        border-radius: 5px;
        font-family: Arial;
    ">
        <h4 style="margin-top:0;">Poblaciones</h4>
        <div style="display: grid; grid-template-columns: max-content max-content; gap: 5px;">
            <div style="width:15px;height:15px;background:#FF0000;"></div><span>Fuenlabrada</span>
            <div style="width:15px;height:15px;background:#0000FF;"></div><span>Leganés</span>
            <div style="width:15px;height:15px;background:#00AA00;"></div><span>Getafe</span>
            <div style="width:15px;height:15px;background:#AA00AA;"></div><span>Alcorcón</span>
        </div>
    </div>
    ''')
    
    map_madrid.add_control(legend_html)
    
    # 8. Force display
    display(map_madrid)
    
    # 9. Debug output
    print(f"Total markers added: {ds_cinturon_sur.shape[0]}")
    print("Map should be visible now with colored markers")
else:
    print("No valid data found after coordinate cleaning")
    display(Map(center=(40.35, -3.8), zoom=10))
# Out:
# Map(center=[40.3, -3.7], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out…
# Total markers added: 907
# Map should be visible now with colored markers
